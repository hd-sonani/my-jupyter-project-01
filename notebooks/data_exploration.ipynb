# %%
import pandas as pd

# %%
df = pd.read_csv("../data/students.csv")

# %%
print(df.head())

# %%
print(df.info())

# %%
avg_marks = df["marks"].mean()
print(avg_marks)

# %%
highest_marks = df["marks"].max()
print(highest_marks)

# %%
low_marks = df["marks"].min()
print(low_marks)

# %%
print(df["marks"])

# %%
print(df["name"])

# %%
print(df.loc[0,"name"])

# %%
print(df.query("marks>90 and age>=20"))

# %%
print(df.shape[0])
